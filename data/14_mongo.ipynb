# %%
import pandas as pd

# %%
df = pd.read_excel("dataset/14. ВАО_Многоквартирные_дома_с_технико_экономическими_характеристиками.xlsx", )

# %%
df.head(5)
# Out:
#                                                 name  \
# 0                         Адрес из сторонней системы
# 1  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...
# 2  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Со...
# 3  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...
# 4  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Ив...
#
#                                    id  \
# 0  Идентификатор из сторонней системы
# 1                             1520521
# 2                             1526496
# 3                             1502303
# 4                             1502774
#
#                                              address   unom  \
# 0                                       Адрес по БТИ   УНОМ
# 1  город Москва, Суздальская улица, дом 24, корпус 2  31783
# 2      город Москва, улица Сокольнический Вал, дом 4  24231
# 3  город Москва, Новокосинская улица, дом 38, кор...  16560
# 4      город Москва, Малый Купавенский проезд, дом 1  12180
#
# ...

# %%
df = df.drop(columns=["col_1945_del"])

# %%
russian_names = df.iloc[0]
list(russian_names)
# Out:
# ['Адрес из сторонней системы',
#  'Идентификатор из сторонней системы',
#  'Адрес по БТИ',
#  'УНОМ',
#  'Округ',
#  'Район',
#  'Серии проектов',
#  'Количество этажей',
#  'Количество подъездов',
#  'Количество квартир',
#  'Общая площадь',
#  'Общая площадь жилых помещений',
#  'Общая площадь нежилых помещений',
#  'Износ объекта (по БТИ)',
#  ' Материалы стен',
#  'Признак аварийности здания',
#  'Количество пассажирских лифтов',
#  'Количество грузопассажирских лифтов',
#  'Очередность уборки кровли',
#  'Материалы кровли по БТИ',
#  'Типы жилищного фонда',
#  'Статусы МКД']

# %%
rename = {old: new for old, new in zip(df.columns, russian_names)}
df.rename(columns=rename, inplace=True)

# %%
df.drop(index=0, inplace=True)

# %%
df.head()
# Out:
#                           Адрес из сторонней системы  \
# 1  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...
# 2  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Со...
# 3  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...
# 4  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Ив...
# 5  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Из...
#
#   Идентификатор из сторонней системы  \
# 1                            1520521
# 2                            1526496
# 3                            1502303
# 4                            1502774
# 5                            1502277
#
#                                         Адрес по БТИ   УНОМ  \
# 1  город Москва, Суздальская улица, дом 24, корпус 2  31783
# 2      город Москва, улица Сокольнический Вал, дом 4  24231
# 3  город Москва, Новокосинская улица, дом 38, кор...  16560
# 4      город Москва, Малый Купавенский проезд, дом 1  12180
# 5           город Москва, 5-я Парковая улица, дом 52  18617
#
# ...

# %%
df.columns
# Out:
# Index(['Адрес из сторонней системы', 'Идентификатор из сторонней системы',
#        'Адрес по БТИ', 'УНОМ', 'Округ', 'Район', 'Серии проектов',
#        'Количество этажей', 'Количество подъездов', 'Количество квартир',
#        'Общая площадь', 'Общая площадь жилых помещений',
#        'Общая площадь нежилых помещений', 'Износ объекта (по БТИ)',
#        ' Материалы стен', 'Признак аварийности здания',
#        'Количество пассажирских лифтов', 'Количество грузопассажирских лифтов',
#        'Очередность уборки кровли', 'Материалы кровли по БТИ',
#        'Типы жилищного фонда', 'Статусы МКД'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 22

# %%
db_names = [
    "address",
    "external_id",
    "bti_address",
    "unom",
    "county",
    "district",
    "project_series",
    "floors",
    "entrances",
    "apartments",
    "total_area",  # Общая площадь
    "total_living_area",  # Общая жилая площадь
    "total_non_living_area",  # Общая нежилая площадь
    "Depreciation",  # Износ объекта (по БТИ)
    "wall_material",  # Материалы стен
    "emergency_feature",  # Признак аварийности здания
    "passenger_elevator",  # Пассажирские лифты
    "service_elevator",  # Грузовые лифты
    "roof_cleaning_sequence",  # Очередность уборки кровли
    "roof_materials",  # Материалы кровли по БТИ
    "types_of_housing_stock",  # Типы жилищного фонда
    "mkd_state",  # Статусы МКД
]

# %%
df.columns
# Out:
# Index(['Адрес из сторонней системы', 'Идентификатор из сторонней системы',
#        'Адрес по БТИ', 'УНОМ', 'Округ', 'Район', 'Серии проектов',
#        'Количество этажей', 'Количество подъездов', 'Количество квартир',
#        'Общая площадь', 'Общая площадь жилых помещений',
#        'Общая площадь нежилых помещений', 'Износ объекта (по БТИ)',
#        ' Материалы стен', 'Признак аварийности здания',
#        'Количество пассажирских лифтов', 'Количество грузопассажирских лифтов',
#        'Очередность уборки кровли', 'Материалы кровли по БТИ',
#        'Типы жилищного фонда', 'Статусы МКД'],
#       dtype='object')

# %%
# map current column names to db column names
rename = {old: new for old, new in zip(df.columns, db_names)}
df.rename(columns=rename, inplace=True)

# %%
df.head()
# Out:
#                                              address external_id  \
# 1  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...     1520521
# 2  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Со...     1526496
# 3  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Но...     1502303
# 4  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Ив...     1502774
# 5  Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Из...     1502277
#
#                                          bti_address   unom  \
# 1  город Москва, Суздальская улица, дом 24, корпус 2  31783
# 2      город Москва, улица Сокольнический Вал, дом 4  24231
# 3  город Москва, Новокосинская улица, дом 38, кор...  16560
# 4      город Москва, Малый Купавенский проезд, дом 1  12180
# 5           город Москва, 5-я Парковая улица, дом 52  18617
#
#                              county                        district  \
# 1  Восточный административный округ  муниципальный округ Новокосино
# 2  Восточный административный округ  муниципальный округ Сокольники
# ...

# %%
len(df)
# Out:
# 4372

# %%
# count nan values
df.isna().sum()
# Out:
# address                   0
# external_id               0
# bti_address               0
# unom                      0
# county                    0
# district                  0
# project_series            0
# floors                    0
# entrances                 0
# apartments                0
# total_area                0
# total_living_area         0
# total_non_living_area     0
# Depreciation              0
# wall_material             0
# emergency_feature         0
# passenger_elevator        0
# service_elevator          1
# roof_cleaning_sequence    0
# roof_materials            0
# types_of_housing_stock    0
# mkd_state                 0
# dtype: int64

# %%
df["Depreciation"].unique()
# Out:
# array([nan, 0, 17, 14, 21, 34, 29, 20, 16, 28, 27, 8, 30, 9, 46, 6, 40,
#        43, 26, 5, 7, 31, 23, 50, 25, 32, 35, 10, 19, 33, 15, 24, 38, 37,
#        36, 12, 48, 22, 11, 52, 13, 39, 41, 55, 54, 4, 18, 44, 47, 45, 49,
#        3, 42, 53, 69, 63, 58], dtype=object)

# %%
avg = df["Depreciation"].astype(float).mean()
df["Depreciation"] = df["Depreciation"].fillna(avg)

# %%
df["roof_cleaning_sequence"].unique()
# Out:
# array([22289163, 22289162])

# %%
df["roof_cleaning_sequence"] = df["roof_cleaning_sequence"].fillna("22289163")
df["roof_cleaning_sequence"] = df["roof_cleaning_sequence"].astype(int)

# %%
df["entrances"].value_counts()
# Out:
# entrances
# 4     1027
# 3      925
# 1      921
# 2      606
# 6      270
# 5      268
# 8      128
# 7       75
# 10      55
# 9       37
# 12      25
# 14       7
# 0        7
# 11       5
# 15       1
# 13       1
# Name: count, dtype: int64

# %%
df["entrances"] = df["entrances"].fillna(3)
df["entrances"] = df["entrances"].astype(int)

# %%
df["apartments"].value_counts()
# Out:
# apartments
# 80     440
# 60     361
# 84     167
# 144    122
# 72     105
#       ...
# 258      1
# 377      1
# 315      1
# 294      1
# 355      1
# Name: count, Length: 367, dtype: int64

# %%
df["apartments"] = df["apartments"].fillna(60)
df["apartments"] = df["apartments"].astype(int)

# %%
df["passenger_elevator"].value_counts()
# Out:
# passenger_elevator
# 0     1919
# 2      793
# 4      460
# 1      384
# 3      208
# 6      184
# 8      131
# 5      109
# 10      48
# 7       40
# 12      35
# 9       23
# 16      15
# 14      10
# 11       3
# 18       3
# 13       2
# 17       1
# 22       1
# 20       1
# 24       1
# Name: count, dtype: int64

# %%
df["passenger_elevator"] = df["passenger_elevator"].fillna(0)
df["passenger_elevator"] = df["passenger_elevator"].astype(int)

# %%
df["roof_materials"].value_counts()
# Out:
# roof_materials
# 22289201    2963
# 22289204     863
# 22289207     262
# 22289205     237
# 22289214      23
# 22289206       4
# 22289213       3
# 22289211       1
# 22289202       1
# Name: count, dtype: int64

# %%
df["roof_materials"] = df["roof_materials"].fillna("22289201")
df["roof_materials"] = df["roof_materials"].astype(int)

# %%
df["service_elevator"].value_counts()
# Out:
# service_elevator
# 0     3562
# 1      226
# 2      225
# 3      127
# 4       99
# 5       45
# 6       37
# 7       18
# 9       11
# 8       11
# 10       3
# 12       3
# 11       2
# 20       1
# 14       1
# Name: count, dtype: int64

# %%
df["service_elevator"] = df["service_elevator"].fillna(0)
df["service_elevator"] = df["service_elevator"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4372 entries, 1 to 4372
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   address                 4372 non-null   object
#  1   external_id             4372 non-null   int64
#  2   bti_address             4372 non-null   object
#  3   unom                    4372 non-null   int64
#  4   county                  4372 non-null   object
#  5   district                4372 non-null   object
#  6   project_series          4372 non-null   object
#  7   floors                  4372 non-null   int64
#  8   entrances               4372 non-null   int64
#  9   apartments              4372 non-null   int64
#  10  total_area              4372 non-null   float64
#  11  total_living_area       4372 non-null   float64
#  12  total_non_living_area   4372 non-null   object
#  13  Depreciation            4372 non-null   float64
# ...

# %%
df["types_of_housing_stock"].value_counts()
# Out:
# types_of_housing_stock
# 42875644    4372
# Name: count, dtype: int64

# %%
df["types_of_housing_stock"] = df["types_of_housing_stock"].fillna("42875644")
df["types_of_housing_stock"] = df["types_of_housing_stock"].astype(int)

# %%
df["mkd_state"].value_counts()
# Out:
# mkd_state
# 58761330    4372
# Name: count, dtype: int64

# %%
df["mkd_state"] = df["mkd_state"].fillna("58761330")
df["mkd_state"] = df["mkd_state"].astype(int)

# %%
df["wall_material"].value_counts()
# Out:
# wall_material
# 179625102    1687
# 2048929      1399
# 179625090     891
# 179625111     107
# 179625107      63
# 179625104      47
# 179625089      41
# 179625119      21
# 261908925      21
# 179625105      19
# 179625091      18
# 179625095      13
# 2048931        12
# 179625080      10
# 179625092       7
# 179625108       4
# 179625101       3
# 179625112       2
# 179625103       2
# 179625097       1
# 179625110       1
# 2048945         1
# 179625113       1
# 179625115       1
# Name: count, dtype: int64

# %%
df["emergency_feature"].value_counts()
# Out:
# emergency_feature
# 22728486    4371
# 22728488       1
# Name: count, dtype: int64

# %%
df["external_id"] = df["external_id"].astype(int)
df["unom"] = df["unom"].astype(int)
df["floors"] = df["floors"].astype(int)
df["total_area"] = df["total_area"].astype(float)
df["total_living_area"] = df["total_living_area"].astype(float)
# df["total_non_living_area"] = df["total_non_living_area"].astype(float)
df["wall_material"] = df["wall_material"].astype(int)
df["emergency_feature"] = df["emergency_feature"].astype(int)

# %%
import pymongo

dsn = "mongodb://Dino:Dino-misos2024@192.168.1.70:54002"
client = pymongo.MongoClient(dsn)
db = client["production"]

# %%
records = df.to_dict(orient="records")

# %%
records[0]
# Out:
# {'address': 'Дом по адресу РФ, г. Москва, вн.тер.г. м.о. Новокосино, Суздальская ул., д. 24, к. 2',
#  'external_id': 1520521,
#  'bti_address': 'город Москва, Суздальская улица, дом 24, корпус 2',
#  'unom': 31783,
#  'county': 'Восточный административный округ',
#  'district': 'муниципальный округ Новокосино',
#  'project_series': 2048785,
#  'floors': 14,
#  'entrances': 3,
#  'apartments': 130,
#  'total_area': 9210.9,
#  'total_living_area': 8615.3,
#  'total_non_living_area': '595.6',
#  'Depreciation': 20.1248654467169,
#  'wall_material': 2048929,
#  'emergency_feature': 22728486,
#  'passenger_elevator': 6,
#  'service_elevator': 0,
#  'roof_cleaning_sequence': 22289163,
#  'roof_materials': 22289207,
#  'types_of_housing_stock': 42875644,
#  'mkd_state': 58761330}

# %%
mkd = db["mkd"]

# %%
mkd.insert_many(records)
# Out:
# InsertManyResult([ObjectId('666a18ee94dabc1abef5ba16'), ObjectId('666a18ee94dabc1abef5ba17'), ObjectId('666a18ee94dabc1abef5ba18'), ObjectId('666a18ee94dabc1abef5ba19'), ObjectId('666a18ee94dabc1abef5ba1a'), ObjectId('666a18ee94dabc1abef5ba1b'), ObjectId('666a18ee94dabc1abef5ba1c'), ObjectId('666a18ee94dabc1abef5ba1d'), ObjectId('666a18ee94dabc1abef5ba1e'), ObjectId('666a18ee94dabc1abef5ba1f'), ObjectId('666a18ee94dabc1abef5ba20'), ObjectId('666a18ee94dabc1abef5ba21'), ObjectId('666a18ee94dabc1abef5ba22'), ObjectId('666a18ee94dabc1abef5ba23'), ObjectId('666a18ee94dabc1abef5ba24'), ObjectId('666a18ee94dabc1abef5ba25'), ObjectId('666a18ee94dabc1abef5ba26'), ObjectId('666a18ee94dabc1abef5ba27'), ObjectId('666a18ee94dabc1abef5ba28'), ObjectId('666a18ee94dabc1abef5ba29'), ObjectId('666a18ee94dabc1abef5ba2a'), ObjectId('666a18ee94dabc1abef5ba2b'), ObjectId('666a18ee94dabc1abef5ba2c'), ObjectId('666a18ee94dabc1abef5ba2d'), ObjectId('666a18ee94dabc1abef5ba2e'), ObjectId('666a18ee94dabc1abef5
# ...
